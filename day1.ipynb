# %%
a = "hello"
print(a)
print(id(a))
# Out:
# hello
# 1758479797776

# %%
#operator (and or not)
a = 0
b = -100
print(not a and b)
print(a or b)
print(not a)
print(not b)
# Out:
# -100
# -100
# True
# False

# %%
# 1
age = int(input("Enter age: "))
print(age > 18 and age < 60)
# Out:
# False

# %%
# 2
num = int(input("Enter number: "))
print(num > 10 and num < 100)
# Out:
# False

# %%
# 3
username = input("Username: ")
password = input("Password: ")
print(username == "admin" and password == "1234")
# Out:
# False

# %%
# 4
marks = int(input("Enter marks: "))
attendance = int(input("Enter attendance: "))
print(marks > 40 and attendance > 75)
# Out:
# False

# %%
# 5
num = int(-2)
print(num % 2 == 0 and num > 0)
# Out:
# False

# %%
# 1
num = int(0)
print(num == 0 or num == 100)
# Out:
# True

# %%
# 2
role = "manager"
print(role == "admin" or role == "manager")
# Out:
# True

# %%
# 3
num = int(15)
print(num % 2 == 0 or num % 5 == 0)
# Out:
# True

# %%
# 4
marks = int(30)
certificate = input("Sports certificate (yes/no): ")
print(marks > 90 or certificate == "yes")
# Out:
# True

# %%
# 5
temp = int(-40)
print(temp < 0 or temp > 40)
# Out:
# True
