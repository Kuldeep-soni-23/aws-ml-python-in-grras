# %%
# variable
num = 10
print(num)
print(id(num))
print(type(num))

#int 
num1 = 10
print(num1)
print(id(num))
print(id(num1))

#string
name = "Kuldeep"
print("string:" , name)
print(id(name))
print(type(name))

#boolean
kj = "True"
print("Boolean:" , kj)
print(id(kj))
print(type(kj))

#float
num2 = 4.55
print("float:" , num2)
print(id(num2))
print(type(num2))
# Out:
# 10
# 140735831590296
# <class 'int'>
# 10
# 140735831590296
# 140735831590296
# string: Kuldeep
# 2718527566976
# <class 'str'>
# Boolean: True
# 140735831612128
# <class 'str'>
# float: 4.55
# 2718526817872
# <class 'float'>

# %%
if num%2==0:
    print(True)
else:
    print(False)
# Out:
# True

# %%
num_float = 4.3
print(num_float)
# Out:
# 4.3

# %%
roll_no = int(input("Enter the number:"))
print(roll_no)
print(id(roll_no))
print(type(roll_no))
# Out:
# 9
# 140735831590264
# <class 'int'>

# %%
roll_no1 = float(input("Enter the Value"))
print(roll_no1)
print(id(roll_no1))
print(type(roll_no1))
# Out:
# 3.3
# 1991821370896
# <class 'float'>

# %%
name = str(input("Enter the Name: "))
print(name)
print(id(name))
print(type(name))
# Out:
# kuldeep
# 1991823662880
# <class 'str'>

# %%
roll_no4 = bool(input("Enter value: "))
print(roll_no4)
print(type(roll_no4))
# Out:
# True
# <class 'bool'>

# %%
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001CFC0500830>>
# True
