# %% [markdown]
# # File Handling

# %%
f = open("file1.csv","r")
f.read()
# Out:
# 'name,roll no\ndheeraj,123\nkunal,1234\nabhishek,12345\npraveen,12356\nanjali,1234567'

# %%
data2 = open("fill.csv","w")
data2.write("data")
data2 = open("fill.csv","r")
data2.read()
# Out:
# 'data'

# %%
# read and append
data2 = open("fill.csv","r")
data2.read()
 
data2 = open("fill.csv","a")
data2.write(" we are grrasian ")
 
data2 = open("fill.csv","r")
data2.read()
# Out:
# 'data we are grrasian  we are grrasian  we are grrasian  we are grrasian '
